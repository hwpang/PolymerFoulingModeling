# %%
import pandas as pd

# %%
def get_film_rops_1D(
    film_rate_of_productions,
    tray,
    cell_inds,
    rop_names,
    loss_only=False,
    production_only=False,
    N=3,
):
    if isinstance(rop_names, str):
        rop_names = [rop_names]

    cell_ind = cell_inds[0]
    df = film_rate_of_productions[tray, cell_ind]
    df.set_index(["rop_rxnstr", "rop_spcname"], inplace=True, drop=False)

    name_inds = df["rop_spcname"].isin(rop_names)
    rop_rxncomments = df.loc[name_inds, "rop_rxncomment"]
    rop_rxnstrs = df.loc[name_inds, "rop_rxnstr"]
    rops = df.loc[name_inds, "rop"]

    for cell_ind in cell_inds[1:]:
        df = film_rate_of_productions[tray, cell_ind]
        df.set_index(["rop_rxnstr", "rop_spcname"], inplace=True, drop=False)
        name_inds = df["rop_spcname"].isin(rop_names)
        rops += df.loc[name_inds, "rop"]

    if loss_only:
        inds = rops < 0
    elif production_only:
        inds = rops > 0
    else:
        inds = rops != 0

    rops = rops[inds]
    rop_rxncomments = rop_rxncomments[inds]
    rop_rxnstrs = rop_rxnstrs[inds]

    sorted_inds = rops.abs().argsort()[::-1]
    if len(sorted_inds) > N:
        sorted_inds = sorted_inds[:N]

    return (
        rops.iloc[sorted_inds],
        rop_rxncomments.iloc[sorted_inds],
        rop_rxnstrs.iloc[sorted_inds],
    )

# %%
num_cells = 3
cell_inds = range(1, num_cells + 1)
rop_names = ["mass"]
film_rate_of_productions = {}

for tray in [20]:
    for cell_ind in cell_inds:
        path = f"/home/gridsan/hwpang/Jobs/PolymerFoulingModeling/TraceO2Perturbed/trace_oxygen_perturbed_20230718/simulation_results/OXYGEN_1e0_3600.0_32.0/simulation_film_1D_rop_{tray}_3cells_cell{cell_ind}_callback_t0.csv"
        df = pd.read_csv(path)
        df.drop_duplicates(subset=["rop_rxnstr", "rop_spcname"], keep="first", inplace=True)
        film_rate_of_productions[tray, cell_ind] = df

    print(tray)
    get_film_rops_1D(
        film_rate_of_productions,
        tray,
        cell_inds,
        rop_names,
        loss_only=False,
        production_only=False,
        N=3,)
# Out:
# 20

# %%
tray = 40
cell_ind = 1
path = f"/home/gridsan/hwpang/Jobs/PolymerFoulingModeling/TraceO2Perturbed/trace_oxygen_perturbed_20230718/simulation_results/OXYGEN_1e0_3600.0_32.0/simulation_film_1D_rop_{tray}_3cells_cell{cell_ind}_callback_t0.csv"
df = pd.read_csv(path)
df.drop_duplicates(subset=["rop_rxnstr", "rop_spcname", "rop"], keep="first", inplace=True)
df
# df.set_index(["rop_rxnstr", "rop_spcname"], inplace=True, drop=False)
# df.loc[index, :]
# Out:
#                                                rop_rxnstr  \
# 0                    1,3-BUTADIENE(L)+CD<=>CC=CC1CC=CCC1C
# 1                  1,3-BUTADIENE(L)+CD<=>C=CC1CC(C)C=CC1C
# 3             CYCLOPENTADIENE(L)+CD<=>CC=CC1C2C=CC(C2)C1C
# 4             CYCLOPENTADIENE(L)+CD<=>CC1C=CC(C)C2CC=CC12
# 5             CYCLOPENTADIENE(L)+CD<=>CC1C=CC(C)C2CC=CC12
# ...                                                   ...
# 139292      KR+COOH(L,oligomer)<=>CC(C)C+COO.(L,oligomer)
# 139293  PR+allylic_CH(L,oligomer)<=>HP+allylic_C.(L,ol...
# 139294          PR+COOH(L,oligomer)<=>HP+COO.(L,oligomer)
# 139295  OR+allylic_CH(L,oligomer)<=>OH+allylic_C.(L,ol...
# 139296          OR+COOH(L,oligomer)<=>OH+COO.(L,oligomer)
#
#                                            rop_rxncomment rop_spcname  \
# 0              1,3-BUTADIENE(L) + CD Diels-Alder addition          CD
# 1              1,3-BUTADIENE(L) + CD Diels-Alder addition          CD
# 3            CYCLOPENTADIENE(L) + CD Diels-Alder addition          CD
# 4            CYCLOPENTADIENE(L) + CD Diels-Alder addition          CD
# 5            CYCLOPENTADIENE(L) + CD Diels-Alder addition          CD
# ...                                                   ...         ...
# 139292  KR + COOH(L,oligomer) -> inert(S) + COO.(L,oli...        mass
# 139293  PR + allylic_CH(L,oligomer) <=> HP + allylic_C...        mass
# 139294    PR + COOH(L,oligomer) <=> HP + COO.(L,oligomer)        mass
# 139295  OR + allylic_CH(L,oligomer) <=> OH + allylic_C...        mass
# 139296    OR + COOH(L,oligomer) <=> OH + COO.(L,oligomer)        mass
#
#                  rop
# 0      -1.499540e-17
# 1      -2.426342e-16
# 3      -1.983615e-18
# 4      -1.983615e-18
# 5      -3.397209e-18
# ...              ...
# 139292  2.293108e-25
# 139293 -9.521228e-21
# 139294 -1.011914e-23
# 139295  1.603977e-16
# 139296 -1.232235e-36
#
# [139267 rows x 4 columns]
